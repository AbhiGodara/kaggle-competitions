# %% [markdown]
# <a href="https://www.kaggle.com/code/abhishekgodara/fork-of-santa-submission-happy-new-year?scriptVersionId=291042131" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/fork-of-santa-submission-happy-new-year/__results__.html
# /kaggle/input/fork-of-santa-submission-happy-new-year/bbox3
# /kaggle/input/fork-of-santa-submission-happy-new-year/submission.csv
# /kaggle/input/fork-of-santa-submission-happy-new-year/__notebook__.ipynb
# /kaggle/input/fork-of-santa-submission-happy-new-year/__output__.json
# /kaggle/input/fork-of-santa-submission-happy-new-year/custom.css
# /kaggle/input/santa-2025/sample_submission.csv
# /kaggle/input/bettertogether/__results__.html
# /kaggle/input/bettertogether/submission.csv
# /kaggle/input/bettertogether/__notebook__.ipynb
# /kaggle/input/bettertogether/__output__.json
# /kaggle/input/bettertogether/custom.css
# /kaggle/input/simulated-annealing-manual-fun-tree-mover/__results__.html
# /kaggle/input/simulated-annealing-manual-fun-tree-mover/bbox3
# /kaggle/input/simulated-annealing-manual-fun-tree-mover/submission.csv
# /kaggle/input/simulated-annealing-manual-fun-tree-mover/__notebook__.ipynb
# /kaggle/input/simulated-annealing-manual-fun-tree-mover/__output__.json
# /kaggle/input/simulated-annealing-manual-fun-tree-mover/custom.css
# /kaggle/input/intergration-of-existing-result-current-best/submission2.csv
# /kaggle/input/intergration-of-existing-result-current-best/submission4.csv
# /kaggle/input/intergration-of-existing-result-current-best/submission3.csv
# /kaggle/input/intergration-of-existing-result-current-best/submission14.csv
# /kaggle/input/intergration-of-existing-result-current-best/submission16.csv
# /kaggle/input/intergration-of-existing-result-current-best/submission9.csv
# /kaggle/input/intergration-of-existing-result-current-best/__results__.html
# /kaggle/input/intergration-of-existing-result-current-best/submission7.csv
# /kaggle/input/intergration-of-existing-result-current-best/submission6.csv
# /kaggle/input/intergration-of-existing-result-current-best/submission1.csv
# /kaggle/input/intergration-of-existing-result-current-best/submission5.csv
# /kaggle/input/intergration-of-existing-result-current-best/submission11.csv
# /kaggle/input/intergration-of-existing-result-current-best/submission15.csv
# /kaggle/input/intergration-of-existing-result-current-best/submission.csv
# /kaggle/input/intergration-of-existing-result-current-best/__notebook__.ipynb
# /kaggle/input/intergration-of-existing-result-current-best/__output__.json
# /kaggle/input/intergration-of-existing-result-current-best/submission10.csv
# /kaggle/input/intergration-of-existing-result-current-best/submission12.csv
# /kaggle/input/intergration-of-existing-result-current-best/submission8.csv
# /kaggle/input/intergration-of-existing-result-current-best/submission13.csv
# /kaggle/input/intergration-of-existing-result-current-best/custom.css
# /kaggle/input/k/samyakrajbayar/simulated-annealing-manual-fun-tree-mover/__results__.html
# /kaggle/input/k/samyakrajbayar/simulated-annealing-manual-fun-tree-mover/bbox3
# /kaggle/input/k/samyakrajbayar/simulated-annealing-manual-fun-tree-mover/submission.csv
# /kaggle/input/k/samyakrajbayar/simulated-annealing-manual-fun-tree-mover/__notebook__.ipynb
# /kaggle/input/k/samyakrajbayar/simulated-annealing-manual-fun-tree-mover/__output__.json
# /kaggle/input/k/samyakrajbayar/simulated-annealing-manual-fun-tree-mover/custom.css
# /kaggle/input/squeezing-bbox-solution/submission_best.csv
# /kaggle/input/squeezing-bbox-solution/__results__.html
# /kaggle/input/squeezing-bbox-solution/__notebook__.ipynb
# /kaggle/input/squeezing-bbox-solution/__output__.json
# /kaggle/input/squeezing-bbox-solution/custom.css
# /kaggle/input/new-year-same-old-bbox/__results__.html
# /kaggle/input/new-year-same-old-bbox/bbox3
# /kaggle/input/new-year-same-old-bbox/submission.csv
# /kaggle/input/new-year-same-old-bbox/__notebook__.ipynb
# /kaggle/input/new-year-same-old-bbox/__output__.json
# /kaggle/input/new-year-same-old-bbox/custom.css
# /kaggle/input/accelerated-sa-on-2-blocks-196-trees/__results__.html
# /kaggle/input/accelerated-sa-on-2-blocks-196-trees/sa_two_blocks_history.png
# /kaggle/input/accelerated-sa-on-2-blocks-196-trees/submission.csv
# /kaggle/input/accelerated-sa-on-2-blocks-196-trees/__notebook__.ipynb
# /kaggle/input/accelerated-sa-on-2-blocks-196-trees/sa_two_blocks_result.png
# /kaggle/input/accelerated-sa-on-2-blocks-196-trees/__output__.json
# /kaggle/input/accelerated-sa-on-2-blocks-196-trees/custom.css
# /kaggle/input/accelerated-sa-on-2-blocks-196-trees/__results___files/__results___31_1.png
# /kaggle/input/accelerated-sa-on-2-blocks-196-trees/__results___files/__results___28_1.png
# /kaggle/input/accelerated-sa-on-2-blocks-196-trees/__results___files/__results___26_1.png
# /kaggle/input/accelerated-sa-on-2-blocks-196-trees/__results___files/__results___27_1.png
# /kaggle/input/accelerated-sa-on-2-blocks-196-trees/__results___files/__results___32_1.png
# /kaggle/input/accelerated-sa-on-2-blocks-196-trees/__results___files/__results___16_1.png
# /kaggle/input/santa-submission/__results__.html
# /kaggle/input/santa-submission/bbox3
# /kaggle/input/santa-submission/bbox_experiments.log
# /kaggle/input/santa-submission/kaggle_bbox_2026-01-09-23-40.zip
# /kaggle/input/santa-submission/submission.csv
# /kaggle/input/santa-submission/__notebook__.ipynb
# /kaggle/input/santa-submission/__output__.json
# /kaggle/input/santa-submission/custom.css
# /kaggle/input/santa-submission/bbox_sub/submi-n1300_r80_i81.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1500_r50_i50.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1400_r70_i71.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n2000_r50_i55.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n2000_r90_i99.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1100_r60_i57.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1900_r20_i21.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1900_r10_i10.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1500_r90_i94.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1200_r50_i47.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1900_r50_i54.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1500_r30_i28.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1800_r60_i64.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1000_r30_i23.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1100_r20_i13.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1600_r60_i62.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1800_r40_i42.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1200_r70_i69.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n2000_r30_i33.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1700_r50_i52.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1600_r30_i29.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1600_r50_i51.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n2000_r80_i88.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1100_r90_i90.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1500_r60_i61.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1000_r20_i12.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1000_r10_i1.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1300_r30_i26.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1300_r60_i59.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1900_r30_i32.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1400_r20_i16.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1800_r50_i53.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1100_r70_i68.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1700_r10_i8.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1800_r20_i20.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1100_r40_i35.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1500_r20_i17.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1700_r70_i74.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1300_r90_i92.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1200_r20_i14.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1200_r40_i36.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1700_r80_i85.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1900_r40_i43.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1900_r60_i65.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n2000_r40_i44.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1400_r90_i93.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1100_r30_i24.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1000_r50_i45.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1100_r10_i2.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1600_r20_i18.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1700_r30_i30.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1700_r90_i96.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1400_r60_i60.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1300_r10_i4.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1100_r50_i46.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1300_r50_i48.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1200_r90_i91.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1200_r30_i25.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1600_r90_i95.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1500_r80_i83.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1900_r90_i98.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1200_r80_i80.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1400_r10_i5.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1800_r30_i31.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1800_r90_i97.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1000_r90_i89.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1200_r10_i3.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n2000_r10_i11.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1000_r60_i56.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1800_r10_i9.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n2000_r70_i77.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1400_r30_i27.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1600_r70_i73.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1600_r10_i7.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1600_r80_i84.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1300_r20_i15.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1900_r70_i76.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1000_r40_i34.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1700_r40_i41.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1400_r50_i49.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1100_r80_i79.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1600_r40_i40.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1000_r80_i78.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1000_r70_i67.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1800_r80_i86.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1500_r10_i6.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n2000_r60_i66.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n2000_r20_i22.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1500_r40_i39.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1400_r40_i38.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1500_r70_i72.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1300_r40_i37.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1400_r80_i82.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1200_r60_i58.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1700_r20_i19.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1700_r60_i63.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1900_r80_i87.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1800_r70_i75.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1300_r70_i70.csv

# %%
import subprocess
import re
import shutil
import os

# --- 1. Setup Paths & Copy Files ---
INPUT_SUB = '/kaggle/input/santa-submission/submission.csv'
INPUT_BIN = '/kaggle/input/santa-submission/bbox3'
WORKING_DIR = '/kaggle/working/'

print("📂 Setting up environment...")

# Copy submission to working directory
if os.path.exists(INPUT_SUB):
    shutil.copy(INPUT_SUB, os.path.join(WORKING_DIR, 'submission.csv'))
    print(f"✅ Copied {INPUT_SUB} -> ./submission.csv")

# Copy executable to working directory
if os.path.exists(INPUT_BIN):
    shutil.copy(INPUT_BIN, os.path.join(WORKING_DIR, 'bbox3'))
    print(f"✅ Copied {INPUT_BIN} -> ./bbox3")

# Set executable permissions
os.chmod('./bbox3', 0o755)
print("✅ Permissions set for ./bbox3")

import math
import pandas as pd
import numpy as np
from numba import njit

@njit
def make_polygon_template():
    tw=0.15; th=0.2; bw=0.7; mw=0.4; ow=0.25
    tip=0.8; t1=0.5; t2=0.25; base=0.0; tbot=-th
    x=np.array([0,ow/2,ow/4,mw/2,mw/4,bw/2,tw/2,tw/2,-tw/2,-tw/2,-bw/2,-mw/4,-mw/2,-ow/4,-ow/2],np.float64)
    y=np.array([tip,t1,t1,t2,t2,base,base,tbot,tbot,base,base,t2,t2,t1,t1],np.float64)
    return x,y

@njit
def score_group(xs,ys,degs,tx,ty):
    n=xs.size; V=tx.size
    mnx=1e300; mny=1e300; mxx=-1e300; mxy=-1e300
    for i in range(n):
        r=degs[i]*math.pi/180.0
        c=math.cos(r); s=math.sin(r)
        xi=xs[i]; yi=ys[i]
        for j in range(V):
            X=c*tx[j]-s*ty[j]+xi
            Y=s*tx[j]+c*ty[j]+yi
            if X<mnx: mnx=X
            if X>mxx: mxx=X
            if Y<mny: mny=Y
            if Y>mxy: mxy=Y
    side=max(mxx-mnx,mxy-mny)
    return side*side/ n

def strip(a):
    return np.array([float(str(v).replace("s","")) for v in a],np.float64)

def all_csv_files():
    out=[]
    for f in subs:
        out += glob.glob(f + "/*.csv", recursive=False)
    return out

from decimal import Decimal, getcontext

from shapely import affinity
from shapely.geometry import Polygon

# Set precision for Decimal
getcontext().prec = 25
scale_factor = Decimal("1e18")

class ChristmasTree:
    """Represents a single, rotatable Christmas tree of a fixed size."""

    def __init__(self, center_x="0", center_y="0", angle="0"):
        """Initializes the Christmas tree with a specific position and rotation."""
        self.center_x = Decimal(center_x)
        self.center_y = Decimal(center_y)
        self.angle = Decimal(angle)

        trunk_w = Decimal("0.15")
        trunk_h = Decimal("0.2")
        base_w = Decimal("0.7")
        mid_w = Decimal("0.4")
        top_w = Decimal("0.25")
        tip_y = Decimal("0.8")
        tier_1_y = Decimal("0.5")
        tier_2_y = Decimal("0.25")
        base_y = Decimal("0.0")
        trunk_bottom_y = -trunk_h

        initial_polygon = Polygon(
            [
                # Start at Tip
                (Decimal("0.0") * scale_factor, tip_y * scale_factor),
                # Right side - Top Tier
                (top_w / Decimal("2") * scale_factor, tier_1_y * scale_factor),
                (top_w / Decimal("4") * scale_factor, tier_1_y * scale_factor),
                # Right side - Middle Tier
                (mid_w / Decimal("2") * scale_factor, tier_2_y * scale_factor),
                (mid_w / Decimal("4") * scale_factor, tier_2_y * scale_factor),
                # Right side - Bottom Tier
                (base_w / Decimal("2") * scale_factor, base_y * scale_factor),
                # Right Trunk
                (trunk_w / Decimal("2") * scale_factor, base_y * scale_factor),
                (trunk_w / Decimal("2") * scale_factor, trunk_bottom_y * scale_factor),
                # Left Trunk
                (-(trunk_w / Decimal("2")) * scale_factor, trunk_bottom_y * scale_factor),
                (-(trunk_w / Decimal("2")) * scale_factor, base_y * scale_factor),
                # Left side - Bottom Tier
                (-(base_w / Decimal("2")) * scale_factor, base_y * scale_factor),
                # Left side - Middle Tier
                (-(mid_w / Decimal("4")) * scale_factor, tier_2_y * scale_factor),
                (-(mid_w / Decimal("2")) * scale_factor, tier_2_y * scale_factor),
                # Left side - Top Tier
                (-(top_w / Decimal("4")) * scale_factor, tier_1_y * scale_factor),
                (-(top_w / Decimal("2")) * scale_factor, tier_1_y * scale_factor),
            ]
        )
        rotated = affinity.rotate(initial_polygon, float(self.angle), origin=(0, 0))
        self.polygon = affinity.translate(
            rotated, xoff=float(self.center_x * scale_factor), yoff=float(self.center_y * scale_factor)
        )

import pandas as pd
import numpy as np
from decimal import Decimal
from shapely.strtree import STRtree


def to_str(x: Decimal):
    return f"s{float(x)}"


def load_configuration_from_df(n, existing_df):
    """
    Load existing configuration from submission CSV.
    """
    group_data = existing_df[existing_df["id"].str.startswith(f"{n:03d}_")]
    trees = []
    for _, row in group_data.iterrows():
        x = row["x"][1:]  # Remove 's' prefix
        y = row["y"][1:]
        deg = row["deg"][1:]
        trees.append(ChristmasTree(x, y, deg))
    return trees

def get_score(trees, n=None):
    xys = np.concatenate([np.asarray(t.polygon.exterior.xy).T / 1e18 for t in trees])
    min_x, min_y = xys.min(axis=0)
    max_x, max_y = xys.max(axis=0)
    score = max(max_x - min_x, max_y - min_y) ** 2
    if n is not None:
        score /= n
    return score

def has_overlap(trees):
    """Check if any trees overlap"""
    if len(trees) <= 1:
        return False

    polygons = [t.polygon for t in trees]
    tree_index = STRtree(polygons)

    for i, poly in enumerate(polygons):
        indices = tree_index.query(poly)
        for idx in indices:
            if idx == i:
                continue
            if poly.intersects(polygons[idx]) and not poly.touches(polygons[idx]):
                return True
    return False

import pandas as pd

def eval_df_sub(df, verb):
    failed = []
    total_score = 0.0
    for n in range(1, 201):
        trees = load_configuration_from_df(n, df)
        score = get_score(trees, n)
        total_score += score
        if verb:
            print(f"{n:3}  {score:.6f}")
        if has_overlap(trees):
            failed.append(n)

    if len(failed) == 0:
        print("Overlap check was succesfull")
    else:
        print("Overlap check failed for", *failed)

    print(f"Total score: {total_score:.12f}")
    return total_score

def main():
    # Read in current ensemble output and check for overlaps
    df = pd.read_csv("submission.csv")
    initial_score = eval_df_sub(df, False)
    new_score = initial_score
    
    print("Starting bbox3 runs")
    
    import subprocess
    import random
    
    while new_score == initial_score:
        random.seed() # Use a random seed every time; add fixed number for repeatability
        n =  str(random.randint(50,500))
        r = str(random.randint(10,50))
        print(f"#### Running bbox3 for n={n} r={r}")
        subprocess.run(["./bbox3", 
                        "-n", n, 
                        "-r", r])
        df = pd.read_csv("submission.csv")
        new_score = eval_df_sub(df, False)

main()
# Out:
# 📂 Setting up environment...
# ✅ Copied /kaggle/input/new-year-same-old-bbox/submission.csv -> ./submission.csv
# ✅ Copied /kaggle/input/new-year-same-old-bbox/bbox3 -> ./bbox3
# ✅ Permissions set for ./bbox3
# Overlap check was succesfull
# Total score: 70.829248956305
# Starting bbox3 runs
# #### Running bbox3 for n=415 r=36
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.829249
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
#
# ========================================
# Optimization Complete
# Initial Score: 70.829248956305
# Final Score:   70.829248956305
# Improvement:   0.000000000000 (0.00%)
# Total Time:    320.6s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.829248956305
# #### Running bbox3 for n=294 r=21
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.829249
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
#
# ========================================
# Optimization Complete
# Initial Score: 70.829248956305
# Final Score:   70.829248956305
# Improvement:   0.000000000000 (0.00%)
# Total Time:    191.2s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.829248956305
# #### Running bbox3 for n=383 r=10
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.829249
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
#
# ========================================
# Optimization Complete
# Initial Score: 70.829248956305
# Final Score:   70.829248956305
# Improvement:   0.000000000000 (0.00%)
# Total Time:    95.3s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.829248956305
# #### Running bbox3 for n=410 r=20
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.829249
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
#
# ========================================
# Optimization Complete
# Initial Score: 70.829248956305
# Final Score:   70.829248956305
# Improvement:   0.000000000000 (0.00%)
# Total Time:    184.7s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.829248956305
# #### Running bbox3 for n=421 r=23
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.829249
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
#
# ========================================
# Optimization Complete
# Initial Score: 70.829248956305
# Final Score:   70.829248956305
# Improvement:   0.000000000000 (0.00%)
# Total Time:    215.5s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.829248956305
# #### Running bbox3 for n=265 r=40
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.829249
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
#
# ========================================
# Optimization Complete
# Initial Score: 70.829248956305
# Final Score:   70.829248956305
# Improvement:   0.000000000000 (0.00%)
# Total Time:    355.5s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.829248956305
# #### Running bbox3 for n=66 r=20
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.829249
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
#
# ========================================
# Optimization Complete
# Initial Score: 70.829248956305
# Final Score:   70.829248956305
# Improvement:   0.000000000000 (0.00%)
# Total Time:    177.1s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.829248956305
# #### Running bbox3 for n=442 r=49
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.829249
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
# [1] n= 64: 0.350468940229 -> 0.350468939841 (0.0000% better) 🏆
#
# ========================================
# Optimization Complete
# Initial Score: 70.829248956305
# Final Score:   70.829248955917
# Improvement:   0.000000000388 (0.00%)
# Total Time:    444.5s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.829248955917
