# %% [markdown]
# <a href="https://www.kaggle.com/code/abhishekgodara/fork-of-santa-submission-happy-new-year?scriptVersionId=289906446" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/magic-fast-backprop/__results__.html
# /kaggle/input/magic-fast-backprop/submission.csv
# /kaggle/input/magic-fast-backprop/__notebook__.ipynb
# /kaggle/input/magic-fast-backprop/__output__.json
# /kaggle/input/magic-fast-backprop/custom.css
# /kaggle/input/santa-2025-quick-ensemble/__results__.html
# /kaggle/input/santa-2025-quick-ensemble/submission.csv
# /kaggle/input/santa-2025-quick-ensemble/__notebook__.ipynb
# /kaggle/input/santa-2025-quick-ensemble/__output__.json
# /kaggle/input/santa-2025-quick-ensemble/custom.css
# /kaggle/input/santa-2025-quick-ensemble/.virtual_documents/__notebook_source__.ipynb
# /kaggle/input/a-bit-better/__results__.html
# /kaggle/input/a-bit-better/bbox3
# /kaggle/input/a-bit-better/submission.csv
# /kaggle/input/a-bit-better/__notebook__.ipynb
# /kaggle/input/a-bit-better/__output__.json
# /kaggle/input/a-bit-better/custom.css
# /kaggle/input/santa-submission-happy-new-year/__results__.html
# /kaggle/input/santa-submission-happy-new-year/bbox3
# /kaggle/input/santa-submission-happy-new-year/submission.csv
# /kaggle/input/santa-submission-happy-new-year/__notebook__.ipynb
# /kaggle/input/santa-submission-happy-new-year/__output__.json
# /kaggle/input/santa-submission-happy-new-year/custom.css
# /kaggle/input/new-year-same-old-bbox/__results__.html
# /kaggle/input/new-year-same-old-bbox/bbox3
# /kaggle/input/new-year-same-old-bbox/submission.csv
# /kaggle/input/new-year-same-old-bbox/__notebook__.ipynb
# /kaggle/input/new-year-same-old-bbox/__output__.json
# /kaggle/input/new-year-same-old-bbox/custom.css
# /kaggle/input/santa-2025/sample_submission.csv
# /kaggle/input/mysteriously-slightly-better-solution/__results__.html
# /kaggle/input/mysteriously-slightly-better-solution/submission.csv
# /kaggle/input/mysteriously-slightly-better-solution/__notebook__.ipynb
# /kaggle/input/mysteriously-slightly-better-solution/__output__.json
# /kaggle/input/mysteriously-slightly-better-solution/custom.css
# /kaggle/input/santa-submission/__results__.html
# /kaggle/input/santa-submission/bbox3
# /kaggle/input/santa-submission/bbox_experiments.log
# /kaggle/input/santa-submission/submission.csv
# /kaggle/input/santa-submission/kaggle_bbox_2026-01-03-19-33.zip
# /kaggle/input/santa-submission/__notebook__.ipynb
# /kaggle/input/santa-submission/__output__.json
# /kaggle/input/santa-submission/custom.css
# /kaggle/input/santa-submission/bbox_sub/submi-n1500_r50_i50.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1900_r20_i21.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1900_r10_i10.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1200_r50_i47.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1900_r50_i54.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1500_r30_i28.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1000_r30_i23.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1100_r20_i13.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1800_r40_i42.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n2000_r30_i33.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1700_r50_i52.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1600_r30_i29.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1600_r50_i51.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1000_r20_i12.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1000_r10_i1.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1300_r30_i26.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1900_r30_i32.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1400_r20_i16.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1800_r50_i53.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1700_r10_i8.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1800_r20_i20.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1100_r40_i35.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1500_r20_i17.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1200_r20_i14.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1200_r40_i36.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1900_r40_i43.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n2000_r40_i44.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1100_r30_i24.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1000_r50_i45.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1100_r10_i2.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1600_r20_i18.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1700_r30_i30.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1300_r10_i4.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1100_r50_i46.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1300_r50_i48.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1200_r30_i25.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1400_r10_i5.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1800_r30_i31.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1200_r10_i3.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n2000_r10_i11.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1800_r10_i9.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1400_r30_i27.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1600_r10_i7.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1300_r20_i15.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1000_r40_i34.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1700_r40_i41.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1400_r50_i49.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1600_r40_i40.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1500_r10_i6.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n2000_r20_i22.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1500_r40_i39.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1400_r40_i38.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1300_r40_i37.csv
# /kaggle/input/santa-submission/bbox_sub/submi-n1700_r20_i19.csv

# %%
import subprocess
import re
import shutil
import os

# --- 1. Setup Paths & Copy Files ---
INPUT_SUB = '/kaggle/input/magic-fast-backprop/submission.csv'
INPUT_BIN = '/kaggle/input/a-bit-better/bbox3'
WORKING_DIR = '/kaggle/working/'

print("📂 Setting up environment...")

# Copy submission to working directory
if os.path.exists(INPUT_SUB):
    shutil.copy(INPUT_SUB, os.path.join(WORKING_DIR, 'submission.csv'))
    print(f"✅ Copied {INPUT_SUB} -> ./submission.csv")

# Copy executable to working directory
if os.path.exists(INPUT_BIN):
    shutil.copy(INPUT_BIN, os.path.join(WORKING_DIR, 'bbox3'))
    print(f"✅ Copied {INPUT_BIN} -> ./bbox3")

# Set executable permissions
os.chmod('./bbox3', 0o755)
print("✅ Permissions set for ./bbox3")

import math
import pandas as pd
import numpy as np
from numba import njit

@njit
def make_polygon_template():
    tw=0.15; th=0.2; bw=0.7; mw=0.4; ow=0.25
    tip=0.8; t1=0.5; t2=0.25; base=0.0; tbot=-th
    x=np.array([0,ow/2,ow/4,mw/2,mw/4,bw/2,tw/2,tw/2,-tw/2,-tw/2,-bw/2,-mw/4,-mw/2,-ow/4,-ow/2],np.float64)
    y=np.array([tip,t1,t1,t2,t2,base,base,tbot,tbot,base,base,t2,t2,t1,t1],np.float64)
    return x,y

@njit
def score_group(xs,ys,degs,tx,ty):
    n=xs.size; V=tx.size
    mnx=1e300; mny=1e300; mxx=-1e300; mxy=-1e300
    for i in range(n):
        r=degs[i]*math.pi/180.0
        c=math.cos(r); s=math.sin(r)
        xi=xs[i]; yi=ys[i]
        for j in range(V):
            X=c*tx[j]-s*ty[j]+xi
            Y=s*tx[j]+c*ty[j]+yi
            if X<mnx: mnx=X
            if X>mxx: mxx=X
            if Y<mny: mny=Y
            if Y>mxy: mxy=Y
    side=max(mxx-mnx,mxy-mny)
    return side*side/ n

def strip(a):
    return np.array([float(str(v).replace("s","")) for v in a],np.float64)

def all_csv_files():
    out=[]
    for f in subs:
        out += glob.glob(f + "/*.csv", recursive=False)
    return out

from decimal import Decimal, getcontext

from shapely import affinity
from shapely.geometry import Polygon

# Set precision for Decimal
getcontext().prec = 25
scale_factor = Decimal("1e18")

class ChristmasTree:
    """Represents a single, rotatable Christmas tree of a fixed size."""

    def __init__(self, center_x="0", center_y="0", angle="0"):
        """Initializes the Christmas tree with a specific position and rotation."""
        self.center_x = Decimal(center_x)
        self.center_y = Decimal(center_y)
        self.angle = Decimal(angle)

        trunk_w = Decimal("0.15")
        trunk_h = Decimal("0.2")
        base_w = Decimal("0.7")
        mid_w = Decimal("0.4")
        top_w = Decimal("0.25")
        tip_y = Decimal("0.8")
        tier_1_y = Decimal("0.5")
        tier_2_y = Decimal("0.25")
        base_y = Decimal("0.0")
        trunk_bottom_y = -trunk_h

        initial_polygon = Polygon(
            [
                # Start at Tip
                (Decimal("0.0") * scale_factor, tip_y * scale_factor),
                # Right side - Top Tier
                (top_w / Decimal("2") * scale_factor, tier_1_y * scale_factor),
                (top_w / Decimal("4") * scale_factor, tier_1_y * scale_factor),
                # Right side - Middle Tier
                (mid_w / Decimal("2") * scale_factor, tier_2_y * scale_factor),
                (mid_w / Decimal("4") * scale_factor, tier_2_y * scale_factor),
                # Right side - Bottom Tier
                (base_w / Decimal("2") * scale_factor, base_y * scale_factor),
                # Right Trunk
                (trunk_w / Decimal("2") * scale_factor, base_y * scale_factor),
                (trunk_w / Decimal("2") * scale_factor, trunk_bottom_y * scale_factor),
                # Left Trunk
                (-(trunk_w / Decimal("2")) * scale_factor, trunk_bottom_y * scale_factor),
                (-(trunk_w / Decimal("2")) * scale_factor, base_y * scale_factor),
                # Left side - Bottom Tier
                (-(base_w / Decimal("2")) * scale_factor, base_y * scale_factor),
                # Left side - Middle Tier
                (-(mid_w / Decimal("4")) * scale_factor, tier_2_y * scale_factor),
                (-(mid_w / Decimal("2")) * scale_factor, tier_2_y * scale_factor),
                # Left side - Top Tier
                (-(top_w / Decimal("4")) * scale_factor, tier_1_y * scale_factor),
                (-(top_w / Decimal("2")) * scale_factor, tier_1_y * scale_factor),
            ]
        )
        rotated = affinity.rotate(initial_polygon, float(self.angle), origin=(0, 0))
        self.polygon = affinity.translate(
            rotated, xoff=float(self.center_x * scale_factor), yoff=float(self.center_y * scale_factor)
        )

import pandas as pd
import numpy as np
from decimal import Decimal
from shapely.strtree import STRtree


def to_str(x: Decimal):
    return f"s{float(x)}"


def load_configuration_from_df(n, existing_df):
    """
    Load existing configuration from submission CSV.
    """
    group_data = existing_df[existing_df["id"].str.startswith(f"{n:03d}_")]
    trees = []
    for _, row in group_data.iterrows():
        x = row["x"][1:]  # Remove 's' prefix
        y = row["y"][1:]
        deg = row["deg"][1:]
        trees.append(ChristmasTree(x, y, deg))
    return trees

def get_score(trees, n=None):
    xys = np.concatenate([np.asarray(t.polygon.exterior.xy).T / 1e18 for t in trees])
    min_x, min_y = xys.min(axis=0)
    max_x, max_y = xys.max(axis=0)
    score = max(max_x - min_x, max_y - min_y) ** 2
    if n is not None:
        score /= n
    return score

def has_overlap(trees):
    """Check if any trees overlap"""
    if len(trees) <= 1:
        return False

    polygons = [t.polygon for t in trees]
    tree_index = STRtree(polygons)

    for i, poly in enumerate(polygons):
        indices = tree_index.query(poly)
        for idx in indices:
            if idx == i:
                continue
            if poly.intersects(polygons[idx]) and not poly.touches(polygons[idx]):
                return True
    return False

import pandas as pd

def eval_df_sub(df, verb):
    failed = []
    total_score = 0.0
    for n in range(1, 201):
        trees = load_configuration_from_df(n, df)
        score = get_score(trees, n)
        total_score += score
        if verb:
            print(f"{n:3}  {score:.6f}")
        if has_overlap(trees):
            failed.append(n)

    if len(failed) == 0:
        print("Overlap check was succesfull")
    else:
        print("Overlap check failed for", *failed)

    print(f"Total score: {total_score:.12f}")
    return total_score


IMPROVEMENT_TARGET = 0.00001

def main():
    # Read in current ensemble output and check for overlaps
    df = pd.read_csv("submission.csv")
    target_score = eval_df_sub(df, False)
    new_score = target_score
    target_score = target_score - IMPROVEMENT_TARGET
    
    print("Starting bbox3 runs")
    
    import subprocess
    import random
    
    while new_score >= target_score:
        random.seed() # Use a random seed every time; add fixed number for repeatability
        n =  str(random.randint(100,1000))
        r = str(random.randint(10,100))
        print(f"#### Running bbox3 for n={n} r={r}")
        subprocess.run(["./bbox3", 
                        "-n", str(random.randint(100,1000)), 
                        "-r", str(random.randint(10,100))])
        df = pd.read_csv("submission.csv")
        new_score = eval_df_sub(df, False)

main()
# Out:
# 📂 Setting up environment...
# ✅ Copied /kaggle/input/magic-fast-backprop/submission.csv -> ./submission.csv
# ✅ Copied /kaggle/input/a-bit-better/bbox3 -> ./bbox3
# ✅ Permissions set for ./bbox3
# Overlap check was succesfull
# Total score: 70.909436669123
# Starting bbox3 runs
# #### Running bbox3 for n=566 r=57
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.909437
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
# [1] n=112: 0.349004765387 -> 0.349004749933 (0.0000% better) 🏆
# [0] n=180: 0.332140100269 -> 0.332139461626 (0.0002% better) 🏆
# [1] n=108: 0.343602464167 -> 0.343602405236 (0.0000% better) 🏆
# [0] n=178: 0.335544142971 -> 0.335543274057 (0.0003% better) 🏆
# [0] n=177: 0.337439196934 -> 0.337438998770 (0.0001% better) 🏆
# [0] n=156: 0.330012484395 -> 0.330012464310 (0.0000% better) 🏆
# [0] n=154: 0.334182203525 -> 0.334182203323 (0.0000% better) 🏆
# [3] n=  8: 0.386278752624 -> 0.386278575311 (0.0000% better) 🏆
# [2] n=132: 0.341331366480 -> 0.341331362650 (0.0000% better) 🏆
#
# ========================================
# Optimization Complete
# Initial Score: 70.909436669123
# Final Score:   70.909434687589
# Improvement:   0.000001981534 (0.00%)
# Total Time:    194.2s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.909434687589
# #### Running bbox3 for n=224 r=81
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.909435
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
# [0] n=182: 0.330068716765 -> 0.330068689193 (0.0000% better) 🏆
# [0] n=178: 0.335543274057 -> 0.335543054495 (0.0001% better) 🏆
# [0] n=157: 0.342791502397 -> 0.342791475027 (0.0000% better) 🏆
# [1] n=131: 0.343759464978 -> 0.343759219850 (0.0001% better) 🏆
# [1] n=127: 0.346749806444 -> 0.346749697515 (0.0000% better) 🏆
# [1] n=121: 0.351669383143 -> 0.351669334566 (0.0000% better) 🏆
#
# ========================================
# Optimization Complete
# Initial Score: 70.909434687589
# Final Score:   70.909434010448
# Improvement:   0.000000677141 (0.00%)
# Total Time:    442.4s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.909434010448
# #### Running bbox3 for n=737 r=78
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.909434
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
# [3] n=109: 0.340578348674 -> 0.340578333532 (0.0000% better) 🏆
# [0] n=177: 0.337438998770 -> 0.337438757198 (0.0001% better) 🏆
# [0] n=158: 0.343900524122 -> 0.343900490971 (0.0000% better) 🏆
# [1] n= 65: 0.363848480997 -> 0.363848435692 (0.0000% better) 🏆
# [1] n=  8: 0.386278575311 -> 0.386278428848 (0.0000% better) 🏆
#
# ========================================
# Optimization Complete
# Initial Score: 70.909434010448
# Final Score:   70.909433528814
# Improvement:   0.000000481634 (0.00%)
# Total Time:    172.8s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.909433528814
# #### Running bbox3 for n=934 r=94
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.909434
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
# [3] n=112: 0.349004749933 -> 0.349004720556 (0.0000% better) 🏆
# [0] n=177: 0.337438757198 -> 0.337438723836 (0.0000% better) 🏆
# [1] n= 65: 0.363848435692 -> 0.363848383832 (0.0000% better) 🏆
# [2] n=131: 0.343759219850 -> 0.343759116485 (0.0000% better) 🏆
#
# ========================================
# Optimization Complete
# Initial Score: 70.909433528814
# Final Score:   70.909433310851
# Improvement:   0.000000217963 (0.00%)
# Total Time:    683.9s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.909433310851
# #### Running bbox3 for n=758 r=49
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.909433
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
# [0] n=178: 0.335543054495 -> 0.335542990949 (0.0000% better) 🏆
# [0] n=177: 0.337438723836 -> 0.337437125119 (0.0005% better) 🏆
# [0] n=158: 0.343900490971 -> 0.343900380503 (0.0000% better) 🏆
# [0] n=157: 0.342791475027 -> 0.342791464226 (0.0000% better) 🏆
# [0] n=154: 0.334182203323 -> 0.334182166191 (0.0000% better) 🏆
# [1] n=  8: 0.386278428848 -> 0.386278402116 (0.0000% better) 🏆
#
# ========================================
# Optimization Complete
# Initial Score: 70.909433310851
# Final Score:   70.909431463457
# Improvement:   0.000001847395 (0.00%)
# Total Time:    163.0s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.909431463457
# #### Running bbox3 for n=854 r=93
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.909431
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
# [2] n= 65: 0.363848383832 -> 0.363848365562 (0.0000% better) 🏆
# [3] n=131: 0.343759116485 -> 0.343758992356 (0.0000% better) 🏆
#
# ========================================
# Optimization Complete
# Initial Score: 70.909431463457
# Final Score:   70.909431321058
# Improvement:   0.000000142399 (0.00%)
# Total Time:    108.8s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.909431321058
# #### Running bbox3 for n=975 r=12
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.909431
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
# [0] n=180: 0.332139461626 -> 0.332139290751 (0.0001% better) 🏆
# [0] n=157: 0.342791464226 -> 0.342791450828 (0.0000% better) 🏆
#
# ========================================
# Optimization Complete
# Initial Score: 70.909431321058
# Final Score:   70.909431136785
# Improvement:   0.000000184273 (0.00%)
# Total Time:    342.9s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.909431136785
# #### Running bbox3 for n=414 r=69
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.909431
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
# [0] n=  8: 0.386278402116 -> 0.386278113943 (0.0001% better) 🏆
#
# ========================================
# Optimization Complete
# Initial Score: 70.909431136785
# Final Score:   70.909430848612
# Improvement:   0.000000288173 (0.00%)
# Total Time:    331.1s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.909430848612
# #### Running bbox3 for n=702 r=66
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.909431
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
# [0] n=177: 0.337437125119 -> 0.337436209252 (0.0003% better) 🏆
# [0] n=157: 0.342791450828 -> 0.342791409295 (0.0000% better) 🏆
# [2] n=131: 0.343758992356 -> 0.343758984778 (0.0000% better) 🏆
# [2] n=121: 0.351669334566 -> 0.351669326308 (0.0000% better) 🏆
#
# ========================================
# Optimization Complete
# Initial Score: 70.909430848612
# Final Score:   70.909429875375
# Improvement:   0.000000973237 (0.00%)
# Total Time:    485.5s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.909429875375
# #### Running bbox3 for n=449 r=59
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.909430
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
# [0] n=180: 0.332139290751 -> 0.332139054612 (0.0001% better) 🏆
# [0] n=178: 0.335542990949 -> 0.335542933639 (0.0000% better) 🏆
# [1] n=  8: 0.386278113943 -> 0.386277788932 (0.0001% better) 🏆
#
# ========================================
# Optimization Complete
# Initial Score: 70.909429875375
# Final Score:   70.909429256915
# Improvement:   0.000000618460 (0.00%)
# Total Time:    400.9s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.909429256915
# #### Running bbox3 for n=398 r=79
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.909429
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
# [0] n=181: 0.330305589314 -> 0.330305580092 (0.0000% better) 🏆
# [0] n=151: 0.340372339241 -> 0.340372306913 (0.0000% better) 🏆
# [0] n=  8: 0.386277788932 -> 0.386277726010 (0.0000% better) 🏆
# [2] n=131: 0.343758984778 -> 0.343758916684 (0.0000% better) 🏆
#
# ========================================
# Optimization Complete
# Initial Score: 70.909429256915
# Final Score:   70.909429084349
# Improvement:   0.000000172566 (0.00%)
# Total Time:    587.9s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.909429084349
# #### Running bbox3 for n=936 r=49
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.909429
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
# [0] n=180: 0.332139054612 -> 0.332139015170 (0.0000% better) 🏆
# [2] n=131: 0.343758916684 -> 0.343758826565 (0.0000% better) 🏆
#
# ========================================
# Optimization Complete
# Initial Score: 70.909429084349
# Final Score:   70.909428954788
# Improvement:   0.000000129561 (0.00%)
# Total Time:    656.7s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.909428954788
# #### Running bbox3 for n=996 r=59
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.909429
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
# [0] n=  8: 0.386277726010 -> 0.386277408517 (0.0001% better) 🏆
# [3] n=131: 0.343758826565 -> 0.343758820691 (0.0000% better) 🏆
#
# ========================================
# Optimization Complete
# Initial Score: 70.909428954788
# Final Score:   70.909428631422
# Improvement:   0.000000323366 (0.00%)
# Total Time:    619.0s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.909428631422
# #### Running bbox3 for n=907 r=18
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.909429
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
# [0] n=178: 0.335542933639 -> 0.335542816430 (0.0000% better) 🏆
# [0] n=158: 0.343900380503 -> 0.343900339108 (0.0000% better) 🏆
# [0] n=153: 0.336347252223 -> 0.336347243509 (0.0000% better) 🏆
#
# ========================================
# Optimization Complete
# Initial Score: 70.909428631422
# Final Score:   70.909428464102
# Improvement:   0.000000167319 (0.00%)
# Total Time:    691.5s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.909428464102
# #### Running bbox3 for n=884 r=20
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.909428
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
# [1] n= 84: 0.352194158757 -> 0.352194155175 (0.0000% better) 🏆
# [0] n=178: 0.335542816430 -> 0.335542615324 (0.0001% better) 🏆
# [0] n=  8: 0.386277408517 -> 0.386277122965 (0.0001% better) 🏆
#
# ========================================
# Optimization Complete
# Initial Score: 70.909428464102
# Final Score:   70.909427973861
# Improvement:   0.000000490241 (0.00%)
# Total Time:    722.0s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.909427973861
# #### Running bbox3 for n=944 r=65
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.909428
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
# [0] n=178: 0.335542615324 -> 0.335542403303 (0.0001% better) 🏆
#
# ========================================
# Optimization Complete
# Initial Score: 70.909427973861
# Final Score:   70.909427761841
# Improvement:   0.000000212020 (0.00%)
# Total Time:    526.1s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.909427761841
# #### Running bbox3 for n=594 r=33
# Loading submission.csv...
# Loaded 200 configs (N=1 to N=200).
# Initial Total Score: 70.909428
#
# Starting parallel optimization on 200 configurations.
# Using 4 threads (Max Concurrency).
#
# [0] n=178: 0.335542403303 -> 0.335542392662 (0.0000% better) 🏆
# [0] n=  8: 0.386277122965 -> 0.386275209597 (0.0005% better) 🏆
#
# ========================================
# Optimization Complete
# Initial Score: 70.909427761841
# Final Score:   70.909425837832
# Improvement:   0.000001924008 (0.00%)
# Total Time:    359.2s
# ========================================
# Saved results to: submission.csv
# Overlap check was succesfull
# Total score: 70.909425837832
